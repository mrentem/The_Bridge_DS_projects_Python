# %%
import pandas as pd

# %%
thailand = pd.read_csv('dragonboat.csv')
thailand
# Out:
#       # in dst.  # in filtered dst.     result        crew  boat  distance  \
# 0           1.0                 1.0     39.251       China    20       200
# 1           2.0                 2.0     40.330    Thailand    20       200
# 2           3.0                 3.0     41.047       China    20       200
# 3           4.0                 4.0     41.253      Canada    20       200
# 4           5.0                 5.0     41.648    Thailand    20       200
# ...         ...                 ...        ...         ...   ...       ...
# 1825      239.0               239.0  12:28.760   Hong Kong    10      2000
# 1826      240.0               240.0  12:47.000   Singapore    10      2000
# 1827      241.0               241.0  13:06.171       Spain    10      2000
# 1828      242.0               242.0  13:06.560    Thailand    10      2000
# 1829      243.0               243.0  14:52.816       India    10      2000
#
# ...

# %%
len(thailand)
# Out:
# 1830
