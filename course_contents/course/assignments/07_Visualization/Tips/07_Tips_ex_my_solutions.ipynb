# %% [markdown]
# # Tips

# %%
from scipy.stats import norm
import matplotlib.mlab as mlab

import pandas as pd

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns


# print the graphs in the notebook
% matplotlib inline

# set seaborn style to white
sns.set_style("white")
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips = tips.drop(['Unnamed: 0'], axis=1)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
## USING SEABORN: distplot() method which displays a histogram distribution with the fit line or distribution
## line

## ref.: https://seaborn.pydata.org/tutorial/distributions.html

# create histogram
ttbill = sns.distplot(tips.total_bill);

# set lables and titles
ttbill.set(xlabel = 'Value', ylabel = 'Frequency', title = "Total Bill")

# take out the right and upper borders
sns.despine()

# %%
ttbill2 = sns.distplot(tips.total_bill, kde=False, rug=True)

# %%
plt.hist(tips.total_bill, bins=20)

# Plot:

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Total Bill')

plt.show()

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.jointplot(x ="total_bill", y ="tip", data = tips)

## This shows that these two variables are correlated, e.i. the higher the Bill, the higher the tip.

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
## USEFUL LINE OF CODE TO PLOT THE RELATIONSHIP AND DISTRIBUTION OF VARIABLES

sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.stripplot(x = "day", y = "total_bill", data = tips, jitter = True)

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
## jitter=True allows to have a better vision of the variable --- CAN ONLY BE USED WITH CATHEGORICAL VALUES

sns.stripplot(x = "tip", y = "day", hue = "sex", data = tips, jitter = True)

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
# hue="time" because it takes that variable to make a cathegorical

sns.boxplot(x = "day", y = "total_bill", hue = "time", data = tips)

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
# better seaborn style
sns.set(style = "ticks")

# creates FacetGrid
g = sns.FacetGrid(tips, col = "time")
g.map(plt.hist, "tip");

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
# ref.: https://plot.ly/python/facet-plots/

g = sns.FacetGrid(tips, col = "sex", hue = "smoker")
g.map(plt.scatter, "total_bill", "tip", alpha =.7)

g.add_legend();
