# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='http://citibikenyc.com/stations/json')
json_readed = r.json()

# %%
print(json_readed)
# Out:
# 'longitude': -73.90951, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 2, 'stAddress1': 'Central Ave & Covert St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:25:15 AM', 'landMark': ''}, {'id': 3865, 'stationName': 'Knickerbocker Ave & Cooper St', 'availableDocks': 19, 'totalDocks': 24, 'latitude': 40.69081, 'longitude': -73.90448, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 5, 'stAddress1': 'Knickerbocker Ave & Cooper St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:20 AM', 'landMark': ''}, {'id': 3866, 'stationName': 'Wilson Ave & Moffat St', 'availableDocks': 29, 'totalDocks': 32, 'latitude': 40.68906, 'longitude': -73.90506, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 3, 'stAddress1': 'Wilson Ave & Moffat St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:26:30 AM', 'landMark': ''}, {'id': 3867, 'stationName': 'Somers St & Broadway', 'availableDocks': 28, 'totalDocks': 29, 'latitude': 40.67945, 'longitude': -73.90474, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Somers St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:28:09 AM', 'landMark': ''}, {'id': 3868, 'stationName': 'Knickerbocker Ave & Halsey St', 'availableDocks': 18, 'totalDocks': 19, 'latitude': 40.693, 'longitude': -73.90824, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Knickerbocker Ave & Halsey St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:20 AM', 'landMark': ''}, {'id': 3869, 'stationName': 'Van Buren St & Broadway', 'availableDocks': 22, 'totalDocks': 24, 'latitude': 40.692, 'longitude': -73.92617, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 2, 'stAddress1': 'Van Buren St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:25:28 AM', 'landMark': ''}, {'id': 3870, 'stationName': 'Melrose St & Broadway', 'availableDocks': 19, 'totalDocks': 20, 'latitude': 40.697481, 'longitude': -73.935877, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Melrose St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:25:21 AM', 'landMark': ''}, {'id': 3871, 'stationName': 'Bushwick Ave & Furman Ave', 'availableDocks': 27, 'totalDocks': 30, 'latitude': 40.68281, 'longitude': -73.90623, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 3, 'stAddress1': 'Bushwick Ave & Furman Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:10 AM', 'landMark': ''}, {'id': 3872, 'stationName': 'Hancock St & Wyckoff Ave', 'availableDocks': 19, 'totalDocks': 19, 'latitude': 40.6972, 'longitude': -73.90674, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 0, 'stAddress1': 'Hancock St & Wyckoff Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:05 AM', 'landMark': ''}, {'id': 3873, 'stationName': 'Madison St & Cypress Ave', 'availableDocks': 13, 'totalDocks': 17, 'latitude': 40.70068, 'longitude': -73.90742, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 4, 'stAddress1': 'Madison St & Cypress Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStati ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# longitude": -73.90951, "statusValue": "In Service", "statusKey": 1, "availableBikes": 2, "stAddress1": "Central Ave & Covert St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:25:15 AM", "landMark": ""}, {"id": 3865, "stationName": "Knickerbocker Ave & Cooper St", "availableDocks": 19, "totalDocks": 24, "latitude": 40.69081, "longitude": -73.90448, "statusValue": "In Service", "statusKey": 1, "availableBikes": 5, "stAddress1": "Knickerbocker Ave & Cooper St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:27:20 AM", "landMark": ""}, {"id": 3866, "stationName": "Wilson Ave & Moffat St", "availableDocks": 29, "totalDocks": 32, "latitude": 40.68906, "longitude": -73.90506, "statusValue": "In Service", "statusKey": 1, "availableBikes": 3, "stAddress1": "Wilson Ave & Moffat St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:26:30 AM", "landMark": ""}, {"id": 3867, "stationName": "Somers St & Broadway", "availableDocks": 28, "totalDocks": 29, "latitude": 40.67945, "longitude": -73.90474, "statusValue": "In Service", "statusKey": 1, "availableBikes": 1, "stAddress1": "Somers St & Broadway", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:28:09 AM", "landMark": ""}, {"id": 3868, "stationName": "Knickerbocker Ave & Halsey St", "availableDocks": 18, "totalDocks": 19, "latitude": 40.693, "longitude": -73.90824, "statusValue": "In Service", "statusKey": 1, "availableBikes": 1, "stAddress1": "Knickerbocker Ave & Halsey St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:27:20 AM", "landMark": ""}, {"id": 3869, "stationName": "Van Buren St & Broadway", "availableDocks": 22, "totalDocks": 24, "latitude": 40.692, "longitude": -73.92617, "statusValue": "In Service", "statusKey": 1, "availableBikes": 2, "stAddress1": "Van Buren St & Broadway", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:25:28 AM", "landMark": ""}, {"id": 3870, "stationName": "Melrose St & Broadway", "availableDocks": 19, "totalDocks": 20, "latitude": 40.697481, "longitude": -73.935877, "statusValue": "In Service", "statusKey": 1, "availableBikes": 1, "stAddress1": "Melrose St & Broadway", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:25:21 AM", "landMark": ""}, {"id": 3871, "stationName": "Bushwick Ave & Furman Ave", "availableDocks": 27, "totalDocks": 30, "latitude": 40.68281, "longitude": -73.90623, "statusValue": "In Service", "statusKey": 1, "availableBikes": 3, "stAddress1": "Bushwick Ave & Furman Ave", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:27:10 AM", "landMark": ""}, {"id": 3872, "stationName": "Hancock St & Wyckoff Ave", "availableDocks": 19, "totalDocks": 19, "latitude": 40.6972, "longitude": -73.90674, "statusValue": "In Service", "statusKey": 1, "availableBikes": 0, "stAddress1": "Hancock St & Wyckoff Ave", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 05:27:05 AM", "landMark": ""}, {"id": 3873, "stationName": "Madison St & Cypress Ave", "availableDocks": 13, "totalDocks": 17, "latitude": 40.70068, "longitude": -73.90742, "statusValue": "In Service", "statusKey": 1, "availableBikes": 4, "stAddress1": "Madison St & Cypress Ave", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStatio ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
#  '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:28 AM',
#    'landMark': ''},
#   {'id': 3870,
#    'stationName': 'Melrose St & Broadway',
#    'availableDocks': 19,
#    'totalDocks': 20,
#    'latitude': 40.697481,
#    'longitude': -73.935877,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Melrose St & Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:21 AM',
#    'landMark': ''},
#   {'id': 3871,
#    'stationName': 'Bushwick Ave & Furman Ave',
#    'availableDocks': 27,
#    'totalDocks': 30,
#    'latitude': 40.68281,
#    'longitude': -73.90623,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Bushwick Ave & Furman Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:10 AM',
#    'landMark': ''},
#   {'id': 3872,
#    'stationName': 'Hancock St & Wyckoff Ave',
#    'availableDocks': 19,
#    'totalDocks': 19,
#    'latitude': 40.6972,
#    'longitude': -73.90674,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Hancock St & Wyckoff Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:05 AM',
#    'landMark': ''},
#   {'id': 3873,
#    'stationName': 'Madison St & Cypress Ave',
#    'availableDocks': 13,
#    'totalDocks': 17,
#    'latitude': 40.70068,
#    'longitude': -73.90742,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Madison St & Cypress Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:49 AM',
#    'landMark': ''},
#   {'id': 3874,
#    'stationName': 'Menahan St & Seneca Ave',
#    'availableDocks': 13,
#    'totalDocks': 16,
#    'latitude': 40.70461,
#    'longitude': -73.91054,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Menahan St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:06 AM',
#    'landMark': ''},
#   {'id': 3875,
#    'stationName': 'Stephen St & Seneca Ave',
#    'availableDocks': 14,
#    'totalDocks': 15,
#    'latitude': 40.6988,
#    'longitude': -73.9007,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Stephen St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:34 AM',
#    'landMark': ''},
#   {'id': 3876,
#    'stationName': 'Forest Ave & Summerfield St',
#    'availableDocks': 18,
#    'totalDocks': 23,
#    'latitude': 40.69922,
#    'longitude': -73.89795,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Forest Ave & Summerfield St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:36 AM',
#    'landMark': ''},
#   {'id': 3877,
#    'stationName': 'Madison St & Forest Ave',
#    'availableDocks': 15,
#    'totalDocks': 25,
#    'latitude': 40.70555,
#    'longitude': -73.90245,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Madison St & Forest Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:58 AM',
#    'landMark': ''},
#   {'id': 3878,
#    'stationName': 'Cypress Ave & George St',
#    'availableDocks': 17,
#    'totalDocks': 19,
#    'latitude': 40.69812,
#    'longitude': -73.90271,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Cypress Ave & George St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:18 AM',
#    'landMark': ''},
#   {'id': 3879,
#    'stationName': 'Broadway & Madison St',
#    'availableDocks': 22,
#    'totalDocks': 25,
#    'latitude': 40.68822,
#    'longitude': -73.91966,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Broadway & Madison St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:11 AM',
#    'landMark': ''},
#   {'id': 3880,
#    'stationName': 'Willoughby Ave & Onderdonk Ave',
#    'availableDocks': 22,
#    'totalDocks': 27,
#    'latitude': 40.7098,
#    'longitude': -73.91727,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Willoughby Ave & Onderdonk Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:42 AM',
#    'landMark': ''},
#   {'id': 3881,
#    'stationName': '12 Ave & W 125 St',
#    'availableDocks': 5,
#    'totalDocks': 39,
#    'latitude': 40.818299,
#    'longitude': -73.960405,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 33,
#    'stAddress1': '12 Ave & W 125 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:41 AM',
#    'landMark': ''},
#   {'id': 3882,
#    'stationName': 'Norman St & Wyckoff Ave',
#    'availableDocks': 15,
#    'totalDocks': 15,
#    'latitude': 40.69517,
#    'longitude': -73.90311,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Norman St & Wyckoff Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:44 AM',
#    'landMark': ''},
#   {'id': 3883,
#    'stationName': 'Harman St & Seneca Ave',
#    'availableDocks': 6,
#    'totalDocks': 19,
#    'latitude': 40.70577,
#    'longitude': -73.91292,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 13,
#    'stAddress1': 'Harman St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:50 AM',
#    'landMark': ''},
#   {'id': 3884,
#    'stationName': 'Centre St & Seneca Ave',
#    'availableDocks': 21,
#    'totalDocks': 23,
#    'latitude': 40.69969,
#    'longitude': -73.9022,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Centre St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:33 AM',
#    'landMark': ''},
#   {'id': 3885,
#    'stationName': 'Onderdonk Ave & Gates Ave',
#    'availableDocks': 16,
#    'totalDocks': 19,
#    'latitude': 40.70413,
#    'longitude': -73.90737,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Onderdonk Ave & Gates Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:59 AM',
#    'landMark': ''},
#   {'id': 3886,
#    'stationName': 'Menahan St & Onderdonk Ave',
#    'availableDocks': 20,
#    'totalDocks': 20,
#    'latitude': 40.70553,
#    'longitude': -73.9096,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Menahan St & Onderdonk Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:07 AM',
#    'landMark': ''},
#   {'id': 3887,
#    'stationName': 'Flushing Ave & Woodward Ave',
#    'availableDocks': 19,
#    'totalDocks': 21,
#    'latitude': 40.71246,
#    'longitude': -73.91873,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Flushing Ave & Woodward Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:56 AM',
#    'landMark': ''},
#   {'id': 3888,
#    'stationName': 'Woodward Ave & Harman St',
#    'availableDocks': 17,
#    'totalDocks': 19,
#    'latitude': 40.70793,
#    'longitude': -73.91092,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Woodward Ave & Harman St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:25 AM',
#    'landMark': ''},
#   {'id': 3890,
#    'stationName': 'Grove St & Broadway',
#    'availableDocks': 23,
#    'totalDocks': 31,
#    'latitude': 40.69047,
#    'longitude': -73.923511,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 8,
#    'stAddress1': 'Grove St & Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:07 AM',
#    'landMark': ''},
#   {'id': 3891,
#    'stationName': 'Irving Ave & Palmetto St',
#    'availableDocks': 19,
#    'totalDocks': 20,
#    'latitude': 40.698,
#    'longitude': -73.9127,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Irving Ave & Palmetto St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:59 AM',
#    'landMark': ''},
#   {'id': 3892,
#    'stationName': '38 Ave & 29 St',
#    'availableDocks': 17,
#    'totalDocks': 19,
#    'latitude': 40.75473,
#    'longitude': -73.93367,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': '38 Ave & 29 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:48 AM',
#    'landMark': ''},
#   {'id': 3893,
#    'stationName': 'Rockaway Ave & Bainbridge St',
#    'availableDocks': 22,
#    'totalDocks': 25,
#    'latitude': 40.68319988172761,
#    'longitude': -73.91166642308235,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Rockaway Ave & Bainbridge St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:59 AM',
#    'landMark': ''},
#   {'id': 3895,
#    'stationName': 'Cypress Ave & Palmetto St',
#    'availableDocks': 21,
#    'totalDocks': 25,
#    'latitude': 40.701573408737914,
#    'longitude': -73.90876293182373,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Cypress Ave & Palmetto St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:17 AM',
#    'landMark': ''},
#   {'id': 3896,
#    'stationName': 'Madison St & Seneca Ave',
#    'availableDocks': 16,
#    'totalDocks': 22,
#    'latitude': 40.70183,
#    'longitude': -73.90625,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'Madison St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:07 AM',
#    'landMark': ''},
#   {'id': 3897,
#    'stationName': 'Onderdonk Ave & Dekalb Ave',
#    'availableDocks': 15,
#    'totalDocks': 17,
#    'latitude': 40.70863,
#    'longitude': -73.91497,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Onderdonk Ave & Dekalb Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:22 AM',
#    'landMark': ''},
#   {'id': 3898,
#    'stationName': 'E 63 St & 3 Ave',
#    'availableDocks': 57,
#    'totalDocks': 57,
#    'latitude': 40.763954,
#    'longitude': -73.9646,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'E 63 St & 3 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:32 AM',
#    'landMark': ''},
#   {'id': 3899,
#    'stationName': 'Manhattan Av & Leonard St',
#    'availableDocks': 12,
#    'totalDocks': 18,
#    'latitude': 40.72084,
#    'longitude': -73.94844,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'Manhattan Av & Leonard St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:49 AM',
#    'landMark': ''},
#   {'id': 3900,
#    'stationName': 'Morgan Ave & Lombardy St',
#    'availableDocks': 25,
#    'totalDocks': 30,
#    'latitude': 40.72226,
#    'longitude': -73.93889,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Morgan Ave & Lombardy St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:28 AM',
#    'landMark': ''},
#   {'id': 3901,
#    'stationName': 'Stanhope St & Fairview Ave',
#    'availableDocks': 17,
#    'totalDocks': 17,
#    'latitude': 40.70998,
#    'longitude': -73.91116,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Stanhope St & Fairview Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:03 AM',
#    'landMark': ''},
#   {'id': 3902,
#    'stationName': 'Fairview Ave & Linden St',
#    'availableDocks': 17,
#    'totalDocks': 19,
#    'latitude': 40.70694,
#    'longitude': -73.90632,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Fairview Ave & Linden St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:29 AM',
#    'landMark': ''},
#   {'id': 3903,
#    'stationName': 'Jefferson Ave & Evergreen Ave',
#    'availableDocks': 15,
#    'totalDocks': 17,
#    'latitude': 40.68989,
#    'longitude': -73.91458,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Jefferson Ave & Evergreen Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:41 AM',
#    'landMark': ''},
#   {'id': 3905,
#    'stationName': '4 Ave & E 12 St',
#    'availableDocks': 0,
#    'totalDocks': 27,
#    'latitude': 40.732647,
#    'longitude': -73.99011,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 27,
#    'stAddress1': '4 Ave & E 12 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:51 AM',
#    'landMark': ''},
#   {'id': 3907,
#    'stationName': 'Central Ave & Melrose St',
#    'availableDocks': 16,
#    'totalDocks': 17,
#    'latitude': 40.70112,
#    'longitude': -73.93039,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Central Ave & Melrose St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:02 AM',
#    'landMark': ''},
#   {'id': 3909,
#    'stationName': 'Madison St & Woodward Ave',
#    'availableDocks': 16,
#    'totalDocks': 20,
#    'latitude': 40.70408,
#    'longitude': -73.90408,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Madison St & Woodward Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:46 AM',
#    'landMark': ''},
#   {'id': 3910,
#    'stationName': 'Greene Ave & Grandview Ave',
#    'availableDocks': 12,
#    'totalDocks': 17,
#    'latitude': 40.709697,
#    'longitude': -73.907856,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Greene Ave & Grandview Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:18 AM',
#    'landMark': ''},
#   {'id': 3911,
#    'stationName': 'Wyckoff St & Nevins St',
#    'availableDocks': 5,
#    'totalDocks': 22,
#    'latitude': 40.683426,
#    'longitude': -73.984275,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 17,
#    'stAddress1': 'Wyckoff St & Nevins St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:59 AM',
#    'landMark': ''},
#   {'id': 3913,
#    'stationName': 'Sands St Gate',
#    'availableDocks': 5,
#    'totalDocks': 19,
#    'latitude': 40.699569,
#    'longitude': -73.979827,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 14,
#    'stAddress1': 'Sands St Gate',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:27:33 AM',
#    'landMark': ''},
#   {'id': 3914,
#    'stationName': 'West End Ave & W 78 St',
#    'availableDocks': 19,
#    'totalDocks': 39,
#    'latitude': 40.783786,
#    'longitude': -73.981687,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 20,
#    'stAddress1': 'West End Ave & W 78 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:30 AM',
#    'landMark': ''},
#   {'id': 3916,
#    'stationName': 'Pearl St & Peck Slip',
#    'availableDocks': 1,
#    'totalDocks': 45,
#    'latitude': 40.708485,
#    'longitude': -74.002751,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 44,
#    'stAddress1': 'Pearl St & Peck Slip',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:25:57 AM',
#    'landMark': ''},
#   {'id': 3917,
#    'stationName': 'Willoughby St & Ashland Pl',
#    'availableDocks': 21,
#    'totalDocks': 31,
#    'latitude': 40.69178,
#    'longitude': -73.97877,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Willoughby St & Ashland Pl',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:28:57 AM',
#    'landMark': ''},
#   {'id': 3918,
#    'stationName': 'Avenue D & E 8 St',
#    'availableDocks': 1,
#    'totalDocks': 30,
#    'latitude': 40.72387,
#    'longitude': -73.975767,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 28,
#    'stAddress1': 'Avenue D & E 8 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-11 05:26:38 AM',
#    'landMark': ''}]}

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#               executionTime                                    stationBeanList
# 0    2020-03-11 05:29:04 AM  {'id': 304, 'stationName': 'Broadway & Battery...
# 1    2020-03-11 05:29:04 AM  {'id': 3255, 'stationName': '8 Ave & W 31 St',...
# 2    2020-03-11 05:29:04 AM  {'id': 72, 'stationName': 'W 52 St & 11 Ave', ...
# 3    2020-03-11 05:29:04 AM  {'id': 79, 'stationName': 'Franklin St & W Bro...
# 4    2020-03-11 05:29:04 AM  {'id': 82, 'stationName': 'St James Pl & Pearl...
# ..                      ...                                                ...
# 930  2020-03-11 05:29:04 AM  {'id': 3913, 'stationName': 'Sands St Gate', '...
# 931  2020-03-11 05:29:04 AM  {'id': 3914, 'stationName': 'West End Ave & W ...
# 932  2020-03-11 05:29:04 AM  {'id': 3916, 'stationName': 'Pearl St & Peck S...
# 933  2020-03-11 05:29:04 AM  {'id': 3917, 'stationName': 'Willoughby St & A...
# 934  2020-03-11 05:29:04 AM  {'id': 3918, 'stationName': 'Avenue D & E 8 St...
#
# [935 rows x 2 columns]

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
with open('data_indented.json', 'r') as outfile:
    json_readed = json.load(outfile)
    for dict_ in json_readed["stationBeanList"]:
        print(dict_)
        break
# Out:
# {'id': 304, 'stationName': 'Broadway & Battery Pl', 'availableDocks': 8, 'totalDocks': 33, 'latitude': 40.70463334, 'longitude': -74.01361706, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 24, 'stAddress1': 'Broadway & Battery Pl', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:25:28 AM', 'landMark': ''}

# %% [markdown]
# 1. Leemos data_indented.json
# 2. Cargamos el contenido en una variable
# 3. Cogemos el contenido de la key/columna "stationBeanList"

# %%
with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    real_json_list = json_readed["stationBeanList"]  # Real json

# %% [markdown]
# 1. Mostramos cómo es el principio de la key "stationBeanList"
# 2. Quitamos los corchetes del principio y final para que quede en formato diccionario

# %%
print(str(real_json_list)[:50])
# Out:
# [{'id': 304, 'stationName': 'Broadway & Battery Pl

# %%
real_json_str = str(real_json_list)[1:-1]
# Out:
# [{'id

# %% [markdown]
# 1. Con dumps, cargamos el contenido de un diccionario a formato string
# 2. Con loads, cargamos el contenido de un string a formato json formal.

# %%
print(str(real_json_str)[:65])
# Out:
# {'id': 304, 'stationName': 'Broadway & Battery Pl', 'availableDoc

# %%
real_json = json.dumps(real_subjson_str)
final_json = json.loads(real_json)
print(final_json)
# Out:
#  'longitude': -73.90951, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 2, 'stAddress1': 'Central Ave & Covert St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:25:15 AM', 'landMark': ''}, {'id': 3865, 'stationName': 'Knickerbocker Ave & Cooper St', 'availableDocks': 19, 'totalDocks': 24, 'latitude': 40.69081, 'longitude': -73.90448, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 5, 'stAddress1': 'Knickerbocker Ave & Cooper St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:20 AM', 'landMark': ''}, {'id': 3866, 'stationName': 'Wilson Ave & Moffat St', 'availableDocks': 29, 'totalDocks': 32, 'latitude': 40.68906, 'longitude': -73.90506, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 3, 'stAddress1': 'Wilson Ave & Moffat St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:26:30 AM', 'landMark': ''}, {'id': 3867, 'stationName': 'Somers St & Broadway', 'availableDocks': 28, 'totalDocks': 29, 'latitude': 40.67945, 'longitude': -73.90474, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Somers St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:28:09 AM', 'landMark': ''}, {'id': 3868, 'stationName': 'Knickerbocker Ave & Halsey St', 'availableDocks': 18, 'totalDocks': 19, 'latitude': 40.693, 'longitude': -73.90824, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Knickerbocker Ave & Halsey St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:20 AM', 'landMark': ''}, {'id': 3869, 'stationName': 'Van Buren St & Broadway', 'availableDocks': 22, 'totalDocks': 24, 'latitude': 40.692, 'longitude': -73.92617, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 2, 'stAddress1': 'Van Buren St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:25:28 AM', 'landMark': ''}, {'id': 3870, 'stationName': 'Melrose St & Broadway', 'availableDocks': 19, 'totalDocks': 20, 'latitude': 40.697481, 'longitude': -73.935877, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Melrose St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:25:21 AM', 'landMark': ''}, {'id': 3871, 'stationName': 'Bushwick Ave & Furman Ave', 'availableDocks': 27, 'totalDocks': 30, 'latitude': 40.68281, 'longitude': -73.90623, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 3, 'stAddress1': 'Bushwick Ave & Furman Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:10 AM', 'landMark': ''}, {'id': 3872, 'stationName': 'Hancock St & Wyckoff Ave', 'availableDocks': 19, 'totalDocks': 19, 'latitude': 40.6972, 'longitude': -73.90674, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 0, 'stAddress1': 'Hancock St & Wyckoff Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 05:27:05 AM', 'landMark': ''}, {'id': 3873, 'stationName': 'Madison St & Cypress Ave', 'availableDocks': 13, 'totalDocks': 17, 'latitude': 40.70068, 'longitude': -73.90742, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 4, 'stAddress1': 'Madison St & Cypress Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStat ...

# %% [markdown]
# 1. Guardamos los datos en un fichero "final.json"
# 2. Cargamos el fichero con pandas

# %%
with open('final.json', 'w+') as outfile:
    json.dump(final_json, outfile, indent=4)

# %%
df_json = pd.read_json("final.json")
df_json
# Out:
#        id                 stationName  availableDocks  totalDocks   latitude  \
# 0     304       Broadway & Battery Pl               8          33  40.704633
# 1    3255             8 Ave & W 31 St               5          19  40.750585
# 2      72            W 52 St & 11 Ave              40          55  40.767272
# 3      79    Franklin St & W Broadway              13          33  40.719116
# 4      82      St James Pl & Pearl St               0          27  40.711174
# ..    ...                         ...             ...         ...        ...
# 930  3913               Sands St Gate               5          19  40.699569
# 931  3914      West End Ave & W 78 St              19          39  40.783786
# 932  3916        Pearl St & Peck Slip               1          45  40.708485
# 933  3917  Willoughby St & Ashland Pl              21          31  40.691780
# 934  3918           Avenue D & E 8 St               1          30  40.723870
#
#      longitude statusValue  statusKey  availableBikes  \
# 0   -74.013617  In Service          1              24
# 1   -73.994685  In Service          1              14
# 2   -73.993929  In Service          1              14
# 3   -74.006667  In Service          1              19
# 4   -74.000165  In Service          1              27
# ..         ...         ...        ...             ...
# 930 -73.979827  In Service          1              14
# 931 -73.981687  In Service          1              20
# 932 -74.002751  In Service          1              44
# 933 -73.978770  In Service          1              10
# 934 -73.975767  In Service          1              28
#
#                      stAddress1 stAddress2 city postalCode location altitude  \
# 0         Broadway & Battery Pl
# 1               8 Ave & W 31 St
# 2              W 52 St & 11 Ave
# 3      Franklin St & W Broadway
# 4        St James Pl & Pearl St
# ..                          ...        ...  ...        ...      ...      ...
# 930               Sands St Gate
# 931      West End Ave & W 78 St
# 932        Pearl St & Peck Slip
# 933  Willoughby St & Ashland Pl
# 934           Avenue D & E 8 St
#
#      testStation   lastCommunicationTime landMark
# 0          False  2020-03-11 05:25:28 AM
# 1          False  2020-03-11 05:26:44 AM
# 2          False  2020-03-11 05:26:51 AM
# 3          False  2020-03-11 05:28:15 AM
# 4          False  2020-03-11 05:28:11 AM
# ..           ...                     ...      ...
# 930        False  2020-03-11 05:27:33 AM
# 931        False  2020-03-11 05:25:30 AM
# 932        False  2020-03-11 05:25:57 AM
# 933        False  2020-03-11 05:28:57 AM
# 934        False  2020-03-11 05:26:38 AM
#
# [935 rows x 18 columns]
