# %% [markdown]
# https://www.practicepython.org/exercise/2014/07/05/18-cows-and-bulls.html

# %% [markdown]
# Create a program that will play the “cows and bulls” game with the user. The game works like this:
#
# Randomly generate a 4-digit number. Ask the user to guess a 4-digit number. For every digit that the user guessed correctly in the correct place, they have a “cow”. For every digit the user guessed correctly in the wrong place is a “bull.” Every time the user makes a guess, tell them how many “cows” and “bulls” they have. Once the user guesses the correct number, the game is over. Keep track of the number of guesses the user makes throughout teh game and tell the user at the end.
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
#   Welcome to the Cows and Bulls Game!
#   Enter a number:
#   >>> 1234
#
#   2 cows, 0 bulls
#
#   >>> 1256
#
#   1 cow, 1 bull
#
#   ...

# %%
def square(num):
    return num * num

if __name__ == "__main__":  # Cuando aparezca esta expresión, esto será lo primer que se ejecute
    user_num = input("Give me a number: ")
    print(square(int(user_num)))

## Es decir, si en algún momento no quiero que se ejecute algo (por ejemplo he importado un módulo, pero no quiero que se ejecute una parte, sólo otra) tengo que colocarlo debajo de if __name__ == "__main__":
## Si te llebas __name__ a otro modulo, ya no es __main__ y ya no lo ejecutaría. Es decir no ejecutará si es una parte importada.
## Son buenas prácticas y un modo de mantener el código ordenado.
# Out:
# 625

# %%
## Generamos un número random, para ello hemos tenido que importar random antes

import random

def random_generate(digits):
    """ Generate a random integer with 'digits' digits"""
    return random.randint(0, digits)

# Con "%.4d", le estamos diciendo que queremos que siempre tenga 4 dígitos. Es decir, si sale 67, recuperará 0067. ---> REPASAR LAS NORMAS DE FORMATO. OJO, EN ESTA CASO NO SOLO HA CAMBIADO EL FORMATO SINO EL TIPO.

x = "%.4d" % random_generate(digits=9999)
print(x)
# Out:
# 3516

# %%
## Pedimos el valor al usuario

#user_number = input("Please, insert a four-digit number:")

## Para hacer las comprobaciones mientras desarrollamos, ponemos en comentario algunas partes y forzamos nuestros valores para hacer siempre las mismas comprobaciones.user_num

# Bulls: 1
# Cows: 2

to_check = "6822"
user_number = "6742"

# %%
def check_chars(char1, char2):
    if char1 == char2: # 'char1' and 'char2' are equals
        return True
    else:
        return False

# %%
def check_numbers_and_return_cows_bulls_numbers(user, check):
    """ This function checks the conditions to identify if they are in the random number and which position"""

    cows_number = 0
    bulls_number = 0

    for i, char in enumerate(check_machine):
        if char in user:  # if True, then one bull or one cow (we don't know yet if the position is right)
            if check_chars(char1=check_machine[1], char2=char): # if i index is the same as "char"
                cows_number += 1
            else:
                bulls_number += 1
    return cows_number, bulls_number

# %%
cows, bulls = check_numbers_and_return_cows_bulls_numbers(user=user_number, check_machine=to_check)

print("Cows:", cows_number)
print("Bulls:", bulls_number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-7637f52d07a1> in <module>
# ----> 1 cows, bulls = check_numbers_and_return_cows_bulls_numbers(user=user_number, check_machine=to_check)
#       2
#       3 print("Cows:", cows_number)
#       4 print("Bulls:", bulls_number)
#
# TypeError: check_numbers_and_return_cows_bulls_numbers() got an unexpected keyword argument 'check_machine'
